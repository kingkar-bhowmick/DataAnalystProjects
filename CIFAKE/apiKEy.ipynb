# %%
KGAT_9980c2fb8ad081336b3fc5b7b0a18c7a

export KAGGLE_API_TOKEN=KGAT_9980c2fb8ad081336b3fc5b7b0a18c7a

mkdir -p ~/.kaggle && echo KGAT_9980c2fb8ad081336b3fc5b7b0a18c7a > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token

kaggle competitions list
